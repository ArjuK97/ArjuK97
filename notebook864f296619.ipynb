# %%
import pandas as pd
import os
os.getcwd()
# Out:
# '/kaggle/working'

# %%
df= pd.read_csv("/kaggle/input/movieratings-20072011/Movie-Ratings.csv")

# %%
df.head()
# Out:
#                     Film      Genre  Rotten Tomatoes Ratings %  \
# 0  (500) Days of Summer      Comedy                         87
# 1            10,000 B.C.  Adventure                          9
# 2             12 Rounds      Action                         30
# 3              127 Hours  Adventure                         93
# 4              17 Again      Comedy                         55
#
#    Audience Ratings %  Budget (million $)  Year of release
# 0                  81                   8             2009
# 1                  44                 105             2008
# 2                  52                  20             2009
# 3                  84                  18             2010
# 4                  70                  20             2009

# %%
len(df)
# Out:
# 559

# %%
df.columns
# Out:
# Index(['Film', 'Genre', 'Rotten Tomatoes Ratings %', 'Audience Ratings %',
#        'Budget (million $)', 'Year of release'],
#       dtype='object')

# %%
df.columns = ['Film', 'Genre', 'CriticRating', 'AudienceRating','BudgetMillions','Year']

# %%
df
# Out:
#                       Film      Genre  CriticRating  AudienceRating  \
# 0    (500) Days of Summer      Comedy            87              81
# 1              10,000 B.C.  Adventure             9              44
# 2               12 Rounds      Action            30              52
# 3                127 Hours  Adventure            93              84
# 4                17 Again      Comedy            55              70
# ..                     ...        ...           ...             ...
# 554          Your Highness     Comedy            26              36
# 555        Youth in Revolt     Comedy            68              52
# 556                 Zodiac   Thriller            89              73
# 557            Zombieland      Action            90              87
# 558              Zookeeper     Comedy            14              42
#
#      BudgetMillions  Year
# 0                 8  2009
# 1               105  2008
# 2                20  2009
# 3                18  2010
# 4                20  2009
# ..              ...   ...
# 554              50  2011
# 555              18  2009
# 556              65  2007
# 557              24  2009
# 558              80  2011
#
# [559 rows x 6 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 559 entries, 0 to 558
# Data columns (total 6 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Film            559 non-null    object
#  1   Genre           559 non-null    object
#  2   CriticRating    559 non-null    int64
#  3   AudienceRating  559 non-null    int64
#  4   BudgetMillions  559 non-null    int64
#  5   Year            559 non-null    int64
# dtypes: int64(4), object(2)
# memory usage: 26.3+ KB

# %%
df.describe()
# Out:
#        CriticRating  AudienceRating  BudgetMillions         Year
# count    559.000000      559.000000      559.000000   559.000000
# mean      47.309481       58.744186       50.236136  2009.152057
# std       26.413091       16.826887       48.731817     1.362632
# min        0.000000        0.000000        0.000000  2007.000000
# 25%       25.000000       47.000000       20.000000  2008.000000
# 50%       46.000000       58.000000       35.000000  2009.000000
# 75%       70.000000       72.000000       65.000000  2010.000000
# max       97.000000       96.000000      300.000000  2011.000000

# %%
df.Film = df.Film.astype('category')

# %%
df.Film
# Out:
# 0      (500) Days of Summer
# 1                10,000 B.C.
# 2                 12 Rounds
# 3                  127 Hours
# 4                  17 Again
#                ...
# 554            Your Highness
# 555          Youth in Revolt
# 556                   Zodiac
# 557              Zombieland
# 558                Zookeeper
# Name: Film, Length: 559, dtype: category
# Categories (559, object): ['(500) Days of Summer ', '10,000 B.C.', '12 Rounds ', '127 Hours', ..., 'Youth in Revolt', 'Zodiac', 'Zombieland ', 'Zookeeper']

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 559 entries, 0 to 558
# Data columns (total 6 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Film            559 non-null    category
#  1   Genre           559 non-null    object
#  2   CriticRating    559 non-null    int64
#  3   AudienceRating  559 non-null    int64
#  4   BudgetMillions  559 non-null    int64
#  5   Year            559 non-null    int64
# dtypes: category(1), int64(4), object(1)
# memory usage: 43.6+ KB

# %%
df.Genre = df.Genre.astype('category')
df.Year = df.Year.astype('category')

# %%
df.Genre
# Out:
# 0         Comedy
# 1      Adventure
# 2         Action
# 3      Adventure
# 4         Comedy
#          ...
# 554       Comedy
# 555       Comedy
# 556     Thriller
# 557       Action
# 558       Comedy
# Name: Genre, Length: 559, dtype: category
# Categories (7, object): ['Action', 'Adventure', 'Comedy', 'Drama', 'Horror', 'Romance', 'Thriller']

# %%
df.Year
# Out:
# 0      2009
# 1      2008
# 2      2009
# 3      2010
# 4      2009
#        ...
# 554    2011
# 555    2009
# 556    2007
# 557    2009
# 558    2011
# Name: Year, Length: 559, dtype: category
# Categories (5, int64): [2007, 2008, 2009, 2010, 2011]

# %%
from matplotlib import pyplot as plt
import seaborn as sns
# %matplotlib inline
import warnings
warnings.filterwarnings('ignore')
# Out:
# /opt/conda/lib/python3.10/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.23.5
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"

# %%
viz1 = sns.jointplot( data = df, x = 'CriticRating', y = 'AudienceRating')

# %%
viz2 = sns.jointplot( data = df, x = 'CriticRating', y = 'AudienceRating', kind='reg')

# %%
viz3 = sns.jointplot( data = df, x = 'CriticRating', y = 'AudienceRating', kind='hex')

# %%
viz4 = sns.distplot(df.AudienceRating)

# %%
sns.set_style('darkgrid')

# %%
viz5 = sns.distplot(df.AudienceRating, bins = 15)

# %%
n1 = plt.hist(df.AudienceRating, bins=15)

# %%
sns.set_style('white') #normal distribution & called as bell curve
n1 = plt.hist(df.AudienceRating, bins=20)

# %%
n1 = plt.hist(df.CriticRating, bins=20)

# %%
plt.hist(df.BudgetMillions)
plt.show()

# %%
plt.hist(df[df.Genre == 'Drama'].BudgetMillions)
plt.show()

# %%
df.head()
# Out:
#                     Film      Genre  CriticRating  AudienceRating  \
# 0  (500) Days of Summer      Comedy            87              81
# 1            10,000 B.C.  Adventure             9              44
# 2             12 Rounds      Action            30              52
# 3              127 Hours  Adventure            93              84
# 4              17 Again      Comedy            55              70
#
#    BudgetMillions  Year
# 0               8  2009
# 1             105  2008
# 2              20  2009
# 3              18  2010
# 4              20  2009

# %%
plt.hist(df[df.Genre == 'Action'].BudgetMillions, bins = 20)
plt.hist(df[df.Genre == 'Thriller'].BudgetMillions, bins = 20)
plt.hist(df[df.Genre == 'Drama'].BudgetMillions, bins = 20)
plt.legend()
plt.show()

# %%
plt.hist([df[df.Genre == 'Action'].BudgetMillions,\
          df[df.Genre == 'Drama'].BudgetMillions, \
          df[df.Genre == 'Thriller'].BudgetMillions, \
          df[df.Genre == 'Comedy'].BudgetMillions],
         bins = 20, stacked = True)
plt.show()

# %%
for gen in df.Genre.cat.categories:
    print(gen)
# Out:
# Action
# Adventure
# Comedy
# Drama
# Horror
# Romance
# Thriller

# %%
vis1 = sns.lmplot(data=df, x='CriticRating', y='AudienceRating',\
                 fit_reg=False,hue='CriticRating')

# %%
vis1 = sns.lmplot(data=df, x='CriticRating', y='AudienceRating',\
                 fit_reg=False)

# %%
vis1 = sns.lmplot(data=df, x='CriticRating', y='AudienceRating',\
                 fit_reg=False, hue = 'Genre')

# %%
vis1 = sns.lmplot(data= df, x='CriticRating', y='AudienceRating',\
                 fit_reg=False, hue = 'Genre',aspect=1)

# %%
 sns.kdeplot(data=df, x='CriticRating', y='AudienceRating')
# Out:
# <Axes: xlabel='CriticRating', ylabel='AudienceRating'>

# %%
k1 = sns.kdeplot(data=df,x='CriticRating',y='AudienceRating', shade = True,shade_lowest=False,cmap='Reds')

# %%
k2 = sns.kdeplot(data=df, x='CriticRating', y='AudienceRating')

# %%
f, axes = plt.subplots(1,2,figsize=(12,8))

k1 = sns.kdeplot(data=df,x='BudgetMillions',y='AudienceRating',ax=axes[0])
k2 = sns.kdeplot(data=df,x='BudgetMillions',y='CriticRating',ax =axes[1])

# %%
w = sns.boxplot(data=df, x='Genre', y = 'CriticRating')

# %%
z = sns.violinplot(data=df, x='Genre', y = 'CriticRating')

# %%
w1 = sns.boxplot(data=df[df.Genre == 'Drama'], x='Year', y = 'CriticRating')

# %%
plt.scatter(df.CriticRating,df.AudienceRating)

# %%
g =sns.FacetGrid (df, row = 'Genre', col = 'Year', hue = 'Genre')
g = g.map(plt.scatter, 'CriticRating', 'AudienceRating' )

# %%
g =sns.FacetGrid (df, row = 'Genre', col = 'Year', hue = 'Genre')
g = g.map(plt.hist, 'BudgetMillions')

# %%
g =sns.FacetGrid (df, row = 'Genre', col = 'Year', hue = 'Genre')
kws = dict(s=50, linewidth=0.5,edgecolor='black')
g = g.map(plt.scatter, 'CriticRating', 'AudienceRating',**kws )

# %%
sns.set_style('darkgrid')
f, axes = plt.subplots (2,2,figsize = (15,15))

k1 = sns.kdeplot(data=df,x='BudgetMillions',y='AudienceRating',ax=axes[0,0])
k2 = sns.kdeplot(data=df,x='BudgetMillions',y='CriticRating',ax = axes[0,1])

k1.set(xlim=(-20,600))
k2.set(xlim=(-20,600))

z = sns.violinplot(data=df[df.Genre=='Drama'], x='Year', y = 'CriticRating', ax=axes[1,0])

k4 = sns.kdeplot(data=df,x='CriticRating',y='AudienceRating',shade = True,shade_lowest=False,cmap='Reds',ax=axes[1,1])

k4b = sns.kdeplot(data=df,x='CriticRating', y='AudienceRating',cmap='Reds',ax = axes[1,1])

plt.show()

# %%
sns.set_style('dark',{'axes.facecolor':'black'})
f, axes = plt.subplots (2,2, figsize = (15,15))

#plot [0,0]
k1 = sns.kdeplot(data=df,x='BudgetMillions',y='AudienceRating', \
                 shade = True, shade_lowest=True,cmap = 'inferno', \
                 ax = axes[0,0])
k1b = sns.kdeplot(data=df,x='BudgetMillions', y='AudienceRating', \
                 cmap = 'cool',ax = axes[0,0])

#plot [0,1]
k2 = sns.kdeplot(data=df,x='BudgetMillions',y='CriticRating',\
                 shade=True, shade_lowest=True, cmap='inferno',\
                 ax = axes[0,1])
k2b = sns.kdeplot(data=df,x='BudgetMillions',y='CriticRating',\
                  cmap = 'cool', ax = axes[0,1])

#plot[1,0]
z = sns.violinplot(data=df[df.Genre=='Drama'], \
                   x='Year', y ='CriticRating', ax=axes[1,0])

#plot[1,1]
k4 = sns.kdeplot(data=df,x='CriticRating',y='AudienceRating', \
                 shade = True,shade_lowest=False,cmap='Blues_r', \
                 ax=axes[1,1])

k4b = sns.kdeplot(data=df,x='CriticRating', y='AudienceRating', \
                  cmap='gist_gray_r',ax = axes[1,1])


k1.set(xlim=(-20,160))
k2.set(xlim=(-20,160))

plt.show()

# %% [markdown]
# The Producer & dicrector should work on the **action & comedy** movie with there $50 millions
